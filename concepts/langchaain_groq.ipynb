# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model="openai/gpt-oss-20b",
    groq_api_key=os.getenv("GROQ_API_KEY")
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[6], line 8
#       4         "You are a helpful assistant that translates English to French. Translate the user sentence.",
#       5     ),
#       6     ("human", "I love programming."),
#       7 ]
# ----> 8 ai_msg = llm.invoke(messages)
#       9 print(ai_msg.content)
#
# File ~/Documents/RAG/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
# ...

# %% [markdown]
# # Chaining

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


output = StrOutputParser()

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that translates {language}. Translate the user sentence."),
    ("human", "{Query}")
])

# %%
def transform_case(res:str) -> str:
    return res.upper()

# %%
chains = prompt | llm | output | transform_case
chains
# Out:
# ChatPromptTemplate(input_variables=['Query', 'language'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='You are a helpful assistant that translates {language}. Translate the user sentence.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['Query'], input_types={}, partial_variables={}, template='{Query}'), additional_kwargs={})])
# ...

# %%
res = chains.invoke({
    "language": "Hinglish",
    "Query": "I love programming."})

res
# Out:
# 'I LOVE PROGRAMMING, YAAR.'

# %% [markdown]
# # Memory

# %%
llm = ChatGroq(
    model="openai/gpt-oss-20b",
    groq_api_key=os.getenv("GROQ_API_KEY")
)

# %%
prompts = [
    {
        "role":"user",
    "content": "What is my name?"
    }
]

res = llm.invoke(prompts)

# %%
res.content
# Out:
# 'I’m not sure what your name is—could you let me know?'

# %%
history = []

while True:
    query = input("User: ")

    if query.lower() in ["exit", "bye", "quit"]:
        print("GoodBye!")
        break

    history.append({"role": "user", "content": query})
    print("User:", query)

    res = llm.invoke(history)
    history.append({"role": "ai", "content": res.content})
    print("AI:", res.content, "\n")
# Out:
# User: Who is PM of India?
# AI: The current Prime Minister of India is **Narendra Modi** (Bharatiya Janata Party). He has been in office since May 26, 2014, and was re‑elected in 2019.
#
# User: What is his age?
# AI: Narendra Modi was born on **17 September 1950**.
# As of today (21 September 2026), he is **76 years old**.
#
# GoodBye!

# %% [markdown]
# # LLM Respons in real time

# %%
llm = ChatGroq(
    model="openai/gpt-oss-20b",
    groq_api_key=os.getenv("GROQ_API_KEY"),
    streaming=True
)

# %%
question = "Can you explain me Gen-AI?"

# %%
response = llm.stream(question)

for chunk in response:
    print(chunk.content, end="")
# Out:
# ### What is Generative AI (Gen‑AI)?
#
# Generative AI refers to a family of artificial‑intelligence systems that **create new content**—text, images, music, code, 3‑D models, and more—rather than merely recognizing or classifying existing data. Think of it as an “AI artist” that can paint, write, or compose on demand.
#
# ---
#
# ## Core Ideas
#
# | Concept | What it means | How it works in practice |
# |---------|---------------|--------------------------|
# | **Generative Model** | A model that learns the underlying distribution of data and can sample from that distribution to produce fresh examples. | Train on millions of examples → learn patterns → generate new samples that look like the training data. |
# | **Probabilistic Output** | The model outputs a probability distribution over possible next tokens (words, pixels, etc.). | The system picks the most probable next token, or samples from the distribution to add variety. |
# ...
