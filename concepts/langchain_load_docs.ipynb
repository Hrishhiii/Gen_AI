# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model="openai/gpt-oss-20b",
    groq_api_key=os.getenv("GROQ_API_KEY")
)

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/Users/hrishhiii/Documents/RAG/data/game_of_thrones_sample.pdf")
# Out:
# /var/folders/wr/v6mv1nt13hjdq1b1ztthb8sc0000gn/T/ipykernel_2335/2152403404.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-09-21T05:21:01+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-09-21T05:21:01+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '/Users/hrishhiii/Documents/RAG/data/game_of_thrones_sample.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Game of Thrones — Sample Document\nA fictional study document for testing PDF/document loaders, text splitting, embeddings, and RAG pipelines.\n1. Series Overview\nGame of Thrones is a fantasy television series set primarily on the fictional continents of Westeros and\nEssos. The story follows several noble families, political alliances, military conflicts, and characters competing\nfor power.\n2. Major Houses\nHouse Stark\nAssociated with Winterfell and the North. The Stark family is known for its emphasis on loyalty, family, and\nhonor.\nHouse Lannister\nA powerful family based at Casterly Rock. The family is closely connected with wealth, political influence, and\nthe Iron Throne.\nHouse Targaryen\nA former ruling dynasty associated with dragons and a long history of rule over Westeros.\nHouse Baratheon\nA prominent Westerosi house whose members become central to the political struggle for the Iron Throne.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-09-21T05:21:01+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-09-21T05:21:01+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '/Users/hrishhiii/Documents/RAG/data/game_of_thrones_sample.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content="3. Important Locations\nWinterfell\nThe ancestral castle of House Stark and an important political center in the North.\nKing's Landing\nThe capital city of Westeros and the location of the Iron Throne.\nThe Wall\nA massive defensive structure separating the Seven Kingdoms from the lands to the north.\nDragonstone\nAn island fortress with strong historical ties to House Targaryen.\nMeereen\nA major city in Slaver's Bay that becomes important during the story in Essos.\n4. Key Themes\nThe series explores power, loyalty, family, ambition, betrayal, leadership, war, political alliances, and the\nconsequences of difficult decisions.\n5. Sample RAG Questions\n\x7f Which house is associated with Winterfell?\n\x7f What is the significance of King's Landing?\n\x7f Which house is associated with dragons?\n\x7f What separates the Seven Kingdoms from the lands to the north?\n\x7f What themes are explored throughout the series?\nNote: This document is an original, condensed study document and is not an excerpt from the copyrighted\nGame of Thrones scripts or books.")]

# %%
len(docs)
# Out:
# 2

# %%
prompt = "What are different houses in Game of Thrones?"

# %%
ans = llm.invoke(prompt)
print(ans.content)
# Out:
# **The Great Houses of Westeros (and a few notable ones beyond)**
#
# > *Note:* The term “house” can refer to any family that owns land, a seat, a coat‑of‑arms, and a claim to titles. Below is a snapshot of the most frequently referenced houses in both the *A Song of Ice and Fire* books and the *Game of Thrones* TV series.
# >
# > 1. **Great Houses** – the most powerful families that hold the Seven Kingdoms.
# > 2. **Other prominent houses** – those that play a major role in the story but are not part of the “Great Houses.”
# > 3. **Minor houses** – countless families that appear in passing; a few are highlighted for their relevance.
#
# ---
#
# ## 1. The Great Houses (Seven Kingdoms)
#
# | House | Seat | Sigil | Motto | Key Members (Books / TV) |
# |-------|------|-------|-------|--------------------------|
# | **Stark** | Winterfell | A grey direwolf on a white field | “Winter is Coming” | Eddard (Ned), Catelyn, Robb, Sansa, Arya, Bran, Jon Snow |
# | **Lannister** | Casterly Rock | A gold lion on a crimson field | “Hear Me Roar” (often mis‑quoted; the real one is “A Lannister always repays”) | Tywin, Joanna, Cersei, Jaime, Tyrion |
# | **Targaryen** | Dragonstone (formerly Valyria) | A red three‑headed dragon on a black field | “Fire and Blood” | Daenerys, Viserys, Aegon the Conqueror (historical) |
# | **Baratheon** | Storm‑\'s‑End | A stag on a blue field | “Ours is the Fury” | Robert, Stannis, Renly |
# | **Greyjoy** | Pyke | A golden kraken on a black field | “We Do Not Breathe” | Balon, Yara, Theon |
# | **Tyrell** | Highgarden | A golden rose on a green field | “Growing Strong” | Mace, Olenna, Loras, Margaery |
# | **Martell** | Sunspear | A red sun pierced by a spear on a gold field | “Unbowed, Unbent, Unbroken” | Doran, Oberyn, Arianne |
# | **Arryn** | The Eyrie | A falcon on a blue field | “We Stand On High” | Jon (Lord), Lysa |
# | **Tully** | Riverrun | A silver trout on a blue field | “Family, Duty, Honor” | Hoster, Catelyn (née), Lysa |
# | **Bolton** | Dreadfort | A black stag on a white field | “Our Word is Our Bond” | Roose, Sansa (married), Ramsay |
# | **Frey** | The Twins | Two white roses on a green field | “A House of Frey, We Are Not The Same” | Walder, Lysa (married to Catelyn) |
#
# > **Why they’re called “Great”:**
# > They hold the Seven Kingdoms’ most important seats, possess the most resources, and are the ones whose claims are recognized by the Crown.
#
# ---
#
# ## 2. Other Prominent Houses
#
# | House | Seat | Sigil | Notable Facts |
# |-------|------|-------|---------------|
# | **Mormont** | Bear Island | A bear on a blue field | Stannis’ ally, Lord Brandon, Lady Lyanna |
# | **Tarth** | Tarth | A black raven on a white field | Home of the “Raven” family, a major naval power |
# | **Clegane** | – | A black stag on a white field | The Clegane brothers: Sandor (The Hound) & Gregor (The Mountain) |
# | **Baratheon of Dragonstone** | Dragonstone | Red dragon | The “Baratheon” branch that survived the war |
# | **Glover** | The Glover | A silver stag on a blue field | Known for the “Glover’s House” in the North |
# | **Umber** | The Umber | A black wolf on a white field | The “Umber” family, often portrayed as “the people” |
# | **Baratheon of Harrenhal** | Harrenhal | A red stag | Historically the “Harrenhal” line, now extinct |
# | **Targaryen of the Iron Islands** | – | – | The “Ironborn” claim to the Targaryen name |
#
# ---
#
# ## 3. Minor (but Noteworthy) Houses
#
# | House | Seat | Sigil | Why they matter |
# |-------|------|-------|-----------------|
# | **Benderson** | – | – | The “Benderson” of the Vale, known for their loyalty to House Arryn |
# | **Mormont** | Bear Island | – | Already listed above as a prominent house |
# | **Dondarrion** | – | – | The “Dondarrion” family, known for their black‑feathered ravens |
# | **Umber** | – | – | The “Umber” family, often portrayed as “the people” |
# | **Baratheon of Harrenhal** | Harrenhal | – | Historically the “Harrenhal” line, now extinct |
# | **Targaryen of the Iron Islands** | – | – | The “Ironborn” claim to the Targaryen name |
#
# ---
#
# ## 4. Houses in Essos
#
# | House | Seat | Sigil | Notable Facts |
# |-------|------|-------|---------------|
# | **House Targaryen** | Valyria (before the fall) | Red dragon | The original Targaryen line that ruled Westeros |
# | **House Khal** | Dothraki Sea | A golden lion | The Khaleesi’s family |
# | **House Baratheon of the North** | – | – | The “Baratheon” line that survived the war |
# | **House Targaryen of the Iron Islands** | – | – | The “Ironborn” claim to the Targaryen name |
#
# ---
#
# ## 5. Quick Reference (Motto‑to‑Sigil)
#
# | Motto | Sigil | House |
# |-------|-------|-------|
# | Winter is Coming | Direwolf | Stark |
# | Hear Me Roar | Lion | Lannister |
# | Fire and Blood | Dragon | Targaryen |
# | Ours is the Fury | Stag | Baratheon |
# | We Do Not Breathe | Kraken | Greyjoy |
# | Growing Strong | Rose | Tyrell |
# | Unbowed, Unbent, Unbroken | Sun‑spier | Martell |
# | We Stand On High | Falcon | Arryn |
# | Family, Duty, Honor | Trout | Tully |
# | Our Word is Our Bond | Stag | Bolton |
# | A House of Frey, We Are Not The Same | Roses | Frey |
#
# ---
#
# ## 6. How to Dive Deeper
#
# | Resource | Why It’s Useful |
# |----------|-----------------|
# | **“A Song of Ice and Fire” series** (books) | The definitive source for lore, history, and house details. |
# | **“Game of Thrones” TV series** | Visual representation of sigils, seats, and family dynamics. |
# | **The Westeros Wiki** | Comprehensive database of every house, including minor ones. |
# | **“The World of Game of Thrones” (board game & card game)** | A fun way to learn house relationships and sigils. |
# | **“The Houses of Westeros” (official guidebook)** | In‑depth look at each house’s history, politics, and lineage. |
#
# ---
#
# ### TL;DR
#
# - **Great Houses**: Stark, Lannister, Targaryen, Baratheon, Greyjoy, Tyrell, Martell, Arryn, Tully, Bolton, Frey.
# - **Other major houses**: Mormont, Tarth, Clegane, etc.
